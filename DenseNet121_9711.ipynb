# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))


# Any results you write to the current directory are saved as output.
# Out:
# ['sample_submission_ns2btKE.csv', 'train', 'test_ApKoW4T.csv']

# %%
train = pd.read_csv('../input/train/train.csv')
train.head()
# Out:
#          image  category
# 0  2823080.jpg         1
# 1  2870024.jpg         1
# 2  2662125.jpg         2
# 3  2900420.jpg         3
# 4  2804883.jpg         2

# %%
from fastai import *

# %%
from fastai.vision import *
from fastai.basics import *

# %%
ls '../input/'
# Out:
# sample_submission_ns2btKE.csv  test_ApKoW4T.csv  train/

# %%
path= Path('../input/train/')

# %%
'../input/train/'
# Out:
# '../input/train/'

# %%
tfms=get_transforms()
tfms
# Out:
# ([RandTransform(tfm=TfmCrop (crop_pad), kwargs={'row_pct': (0, 1), 'col_pct': (0, 1), 'padding_mode': 'reflection'}, p=1.0, resolved={}, do_run=True, is_random=True),
#   RandTransform(tfm=TfmPixel (flip_lr), kwargs={}, p=0.5, resolved={}, do_run=True, is_random=True),
#   RandTransform(tfm=TfmCoord (symmetric_warp), kwargs={'magnitude': (-0.2, 0.2)}, p=0.75, resolved={}, do_run=True, is_random=True),
#   RandTransform(tfm=TfmAffine (rotate), kwargs={'degrees': (-10.0, 10.0)}, p=0.75, resolved={}, do_run=True, is_random=True),
#   RandTransform(tfm=TfmAffine (zoom), kwargs={'scale': (1.0, 1.1), 'row_pct': (0, 1), 'col_pct': (0, 1)}, p=0.75, resolved={}, do_run=True, is_random=True),
#   RandTransform(tfm=TfmLighting (brightness), kwargs={'change': (0.4, 0.6)}, p=0.75, resolved={}, do_run=True, is_random=True),
#   RandTransform(tfm=TfmLighting (contrast), kwargs={'scale': (0.8, 1.25)}, p=0.75, resolved={}, do_run=True, is_random=True)],
#  [RandTransform(tfm=TfmCrop (crop_pad), kwargs={}, p=1.0, resolved={}, do_run=True, is_random=True)])

# %%
data = (ImageList .from_csv(path, folder='images', csv_name='train.csv', cols='image')
       #.use_partial_data(sample_pct = .1, seed= 34)
       .split_by_rand_pct(valid_pct=0.1, seed=34)
       .label_from_df(cols='category')
        .add_test_folder(Path('../input/test_ApKoW4T.csv'))
       .transform(tfms, size = 224)
       .databunch(bs=64)).normalize(imagenet_stats)

# %%
data.show_batch(3, figsize=(6,6), hide_axis=False)

# %%
import os
model_dir="/tmp/model/"
if not os.path.exists ("/tmp/model/"):
    # !mkdir "/tmp/model/"
learn = cnn_learner(data, models.densenet121,model_dir="/tmp/model/",metrics=[FBeta(beta=1),accuracy])
# Out:
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /tmp/.torch/models/densenet121-a639ec97.pth
# 32342954it [00:00, 56691428.11it/s]

# %%
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>f_beta</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.805612</td>
#       <td>0.423531</td>
#       <td>0.845403</td>
#       <td>0.836800</td>
#       <td>01:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.458141</td>
#       <td>0.266318</td>
#       <td>0.902834</td>
#       <td>0.896000</td>
#       <td>01:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.343030</td>
#       <td>0.222930</td>
#       <td>0.920862</td>
#       <td>0.915200</td>
#       <td>01:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.249367</td>
#       <td>0.194069</td>
#       <td>0.928057</td>
#       <td>0.923200</td>
#       <td>01:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.231878</td>
#       <td>0.190952</td>
#       <td>0.924839</td>
#       <td>0.920000</td>
#       <td>01:07</td>
#     </tr>
#   </tbody>
# </table>
# /opt/conda/lib/python3.6/site-packages/fastai/metrics.py:179: UserWarning: average=`binary` was selected for a non binary case. Value for average has now been set to `macro` instead.
#   warn("average=`binary` was selected for a non binary case. Value for average has now been set to `macro` instead.")

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()
len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(15, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(5,5), dpi=120)

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(8, max_lr=slice(5e-4,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>f_beta</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.197366</td>
#       <td>0.173685</td>
#       <td>0.950110</td>
#       <td>0.947200</td>
#       <td>01:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.231629</td>
#       <td>0.241859</td>
#       <td>0.918770</td>
#       <td>0.908800</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.223107</td>
#       <td>0.183259</td>
#       <td>0.935956</td>
#       <td>0.931200</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.172620</td>
#       <td>0.167146</td>
#       <td>0.939277</td>
#       <td>0.934400</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.120670</td>
#       <td>0.174709</td>
#       <td>0.953696</td>
#       <td>0.945600</td>
#       <td>01:09</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.069290</td>
#       <td>0.138881</td>
#       <td>0.957652</td>
#       <td>0.953600</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.057298</td>
#       <td>0.108230</td>
#       <td>0.964631</td>
#       <td>0.960000</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.035241</td>
#       <td>0.106529</td>
#       <td>0.968986</td>
#       <td>0.964800</td>
#       <td>01:09</td>
#     </tr>
#   </tbody>
# </table>
# /opt/conda/lib/python3.6/site-packages/fastai/metrics.py:179: UserWarning: average=`binary` was selected for a non binary case. Value for average has now been set to `macro` instead.
#   warn("average=`binary` was selected for a non binary case. Value for average has now been set to `macro` instead.")

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 5e-5
lrs=np.array([lr/10,lr/3,lr])
learn.unfreeze()
learn.fit(5,lrs)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>f_beta</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.033944</td>
#       <td>0.119746</td>
#       <td>0.966282</td>
#       <td>0.961600</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.027614</td>
#       <td>0.113479</td>
#       <td>0.969487</td>
#       <td>0.964800</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.027128</td>
#       <td>0.111797</td>
#       <td>0.969487</td>
#       <td>0.964800</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.021762</td>
#       <td>0.113832</td>
#       <td>0.966335</td>
#       <td>0.961600</td>
#       <td>01:09</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.021047</td>
#       <td>0.115084</td>
#       <td>0.965960</td>
#       <td>0.961600</td>
#       <td>01:09</td>
#     </tr>
#   </tbody>
# </table>
# /opt/conda/lib/python3.6/site-packages/fastai/metrics.py:179: UserWarning: average=`binary` was selected for a non binary case. Value for average has now been set to `macro` instead.
#   warn("average=`binary` was selected for a non binary case. Value for average has now been set to `macro` instead.")

# %%
train.shape
# Out:
# (6252, 2)

# %%
t  = pd.read_csv('../input/test_ApKoW4T.csv')
t.shape[0]
# Out:
# 2680

# %%
data.add_test(items=[path/'images'/i for i in t['image'].tolist()],label=None)

# %%
data.test_dl
# Out:
# DeviceDataLoader(dl=<torch.utils.data.dataloader.DataLoader object at 0x7f3e50589b70>, device=device(type='cuda'), tfms=[functools.partial(<function _normalize_batch at 0x7f3e52feebf8>, mean=tensor([0.4850, 0.4560, 0.4060]), std=tensor([0.2290, 0.2240, 0.2250]), do_x=True, do_y=False)], collate_fn=<function data_collate at 0x7f3e5a1ce378>)

# %%
preds, y = learn.TTA(beta=0.4,ds_type=DatasetType.Test)

# %%
preds.shape
# Out:
# torch.Size([2680, 5])

# %%
imgName = t['image'].tolist()
imgName
# Out:
# ['1007700.jpg',
#  '1011369.jpg',
#  '1051155.jpg',
#  '1062001.jpg',
#  '1069397.jpg',
#  '1072861.jpg',
#  '1097264.jpg',
#  '1098763.jpg',
#  '1098766.jpg',
#  '1101145.jpg',
#  '1114371.jpg',
#  '1114781.jpg',
#  '1115492.jpg',
#  '1121306.jpg',
#  '1123736.jpg',
#  '1124946.jpg',
#  '1125700.jpg',
#  '1127236.jpg',
#  '1127336.jpg',
#  '1130300.jpg',
#  '1131990.jpg',
#  '1141996.jpg',
#  '1145082.jpg',
#  '1153400.jpg',
#  '1162763.jpg',
#  '1162764.jpg',
#  '1162765.jpg',
#  '1163874.jpg',
#  '1174623.jpg',
#  '1185778.jpg',
#  '1186207.jpg',
#  '1193420.jpg',
#  '1203926.jpg',
#  '1228622.jpg',
#  '1229806.jpg',
#  '1243717.jpg',
#  '1244690.jpg',
#  '1244768.jpg',
#  '1250078.jpg',
#  '1250085.jpg',
#  '1252407.jpg',
#  '1260394.jpg',
#  '1263061.jpg',
#  '1263459.jpg',
#  '1289223.jpg',
#  '1289225.jpg',
#  '1296498.jpg',
#  '1311396.jpg',
#  '1314965.jpg',
#  '1324036.jpg',
#  '1334848.jpg',
#  '1334855.jpg',
#  '1342277.jpg',
#  '1345016.jpg',
#  '1352852.jpg',
#  '1359851.jpg',
#  '1368439.jpg',
#  '1382476.jpg',
#  '1386041.jpg',
#  '1396598.jpg',
#  '1400085.jpg',
#  '1400092.jpg',
#  '1412936.jpg',
#  '1414715.jpg',
#  '1414770.jpg',
#  '1416997.jpg',
#  '1417878.jpg',
#  '1419049.jpg',
#  '1419637.jpg',
#  '1436973.jpg',
#  '1438737.jpg',
#  '1438739.jpg',
#  '1440259.jpg',
#  '1440681.jpg',
#  '1444369.jpg',
#  '1445493.jpg',
#  '1447326.jpg',
#  '1458560.jpg',
#  '1467289.jpg',
#  '1488268.jpg',
#  '1489241.jpg',
#  '1495100.jpg',
#  '1498652.jpg',
#  '1504422.jpg',
#  '1514473.jpg',
#  '1527871.jpg',
#  '1530484.jpg',
#  '1539121.jpg',
#  '1545305.jpg',
#  '1547779.jpg',
#  '1548062.jpg',
#  '1548618.jpg',
#  '1556518.jpg',
#  '1557652.jpg',
#  '1557671.jpg',
#  '1564564.jpg',
#  '1566197.jpg',
#  '1569560.jpg',
#  '1574789.jpg',
#  '1585023.jpg',
#  '1585259.jpg',
#  '1588430.jpg',
#  '1603686.jpg',
#  '1603850.jpg',
#  '1609336.jpg',
#  '1609535.jpg',
#  '1613150.jpg',
#  '1615494.jpg',
#  '1617392.jpg',
#  '1630950.jpg',
#  '1634254.jpg',
#  '1637858.jpg',
#  '1641483.jpg',
#  '1641487.jpg',
#  '1641596.jpg',
#  '1642121.jpg',
#  '1643117.jpg',
#  '1645622.jpg',
#  '1651007.jpg',
#  '1651833.jpg',
#  '1652226.jpg',
#  '1652674.jpg',
#  '1653343.jpg',
#  '1653945.jpg',
#  '1672063.jpg',
#  '1672126.jpg',
#  '1689339.jpg',
#  '1689358.jpg',
#  '1689412.jpg',
#  '1694521.jpg',
#  '1694762.jpg',
#  '1697452.jpg',
#  '1703091.jpg',
#  '1703441.jpg',
#  '1713559.jpg',
#  '1718156.jpg',
#  '1721331.jpg',
#  '1722700.jpg',
#  '1728153.jpg',
#  '1736132.jpg',
#  '1737175.jpg',
#  '1771316.jpg',
#  '1775181.jpg',
#  '1778222.jpg',
#  '1781636.jpg',
#  '1783433.jpg',
#  '1784057.jpg',
#  '1796007.jpg',
#  '1796428.jpg',
#  '1797133.jpg',
#  '1798175.jpg',
#  '1798818.jpg',
#  '1798868.jpg',
#  '1801042.jpg',
#  '1809831.jpg',
#  '1810516.jpg',
#  '1817270.jpg',
#  '1826311.jpg',
#  '1831434.jpg',
#  '1831988.jpg',
#  '1833263.jpg',
#  '1833418.jpg',
#  '1836188.jpg',
#  '1837446.jpg',
#  '1865955.jpg',
#  '1866270.jpg',
#  '1868580.jpg',
#  '1868917.jpg',
#  '1872455.jpg',
#  '1873382.jpg',
#  '1874363.jpg',
#  '1875887.jpg',
#  '1879729.jpg',
#  '1882244.jpg',
#  '1882755.jpg',
#  '1884624.jpg',
#  '1892832.jpg',
#  '1893078.jpg',
#  '1893465.jpg',
#  '1893492.jpg',
#  '1895863.jpg',
#  '1896150.jpg',
#  '1896283.jpg',
#  '1899080.jpg',
#  '1901619.jpg',
#  '1901834.jpg',
#  '1903348.jpg',
#  '1903824.jpg',
#  '1904107.jpg',
#  '1905561.jpg',
#  '1905582.jpg',
#  '1905583.jpg',
#  '1915448.jpg',
#  '1920587.jpg',
#  '1935958.jpg',
#  '1936086.jpg',
#  '1940395.jpg',
#  '1942198.jpg',
#  '1943575.jpg',
#  '1951775.jpg',
#  '1958103.jpg',
#  '1972148.jpg',
#  '1980440.jpg',
#  '1982219.jpg',
#  '1991236.jpg',
#  '2002178.jpg',
#  '2004193.jpg',
#  '2006104.jpg',
#  '2008187.jpg',
#  '2010304.jpg',
#  '2012365.jpg',
#  '2016356.jpg',
#  '2022166.jpg',
#  '2023086.jpg',
#  '2030588.jpg',
#  '2031805.jpg',
#  '2032158.jpg',
#  '2034169.jpg',
#  '2035502.jpg',
#  '2038316.jpg',
#  '2041039.jpg',
#  '2042418.jpg',
#  '2046476.jpg',
#  '2049637.jpg',
#  '2060547.jpg',
#  '2062572.jpg',
#  '2064877.jpg',
#  '2065897.jpg',
#  '2066022.jpg',
#  '2074215.jpg',
#  '2080062.jpg',
#  '2080311.jpg',
#  '2080583.jpg',
#  '2080801.jpg',
#  '2087688.jpg',
#  '2091937.jpg',
#  '2095187.jpg',
#  '2095371.jpg',
#  '2097231.jpg',
#  '2100131.jpg',
#  '2102360.jpg',
#  '2109959.jpg',
#  '2118076.jpg',
#  '2122069.jpg',
#  '2122560.jpg',
#  '2127813.jpg',
#  '2128735.jpg',
#  '2129132.jpg',
#  '2131397.jpg',
#  '2132222.jpg',
#  '2139689.jpg',
#  '2143199.jpg',
#  '2143209.jpg',
#  '2145067.jpg',
#  '2145684.jpg',
#  '2147837.jpg',
#  '2149646.jpg',
#  '2154234.jpg',
#  '2156459.jpg',
#  '2158882.jpg',
#  '2159094.jpg',
#  '2160804.jpg',
#  '2160806.jpg',
#  '2160809.jpg',
#  '2165627.jpg',
#  '2168636.jpg',
#  '2170813.jpg',
#  '2175708.jpg',
#  '2175711.jpg',
#  '2180725.jpg',
#  '2181348.jpg',
#  '2181985.jpg',
#  '2182983.jpg',
#  '2183166.jpg',
#  '2188103.jpg',
#  '2190460.jpg',
#  '2195851.jpg',
#  '2202001.jpg',
#  '2204759.jpg',
#  '2206376.jpg',
#  '2208112.jpg',
#  '2208126.jpg',
#  '2208427.jpg',
#  '2208821.jpg',
#  '2210948.jpg',
#  '2214118.jpg',
#  '2215283.jpg',
#  '2217931.jpg',
#  '2219507.jpg',
#  '2222503.jpg',
#  '2232035.jpg',
#  '2235313.jpg',
#  '2235705.jpg',
#  '2235747.jpg',
#  '2235769.jpg',
#  '2237181.jpg',
#  '2237388.jpg',
#  '2237892.jpg',
#  '2252297.jpg',
#  '2254053.jpg',
#  '2259527.jpg',
#  '2263658.jpg',
#  '2265605.jpg',
#  '2269952.jpg',
#  '2270066.jpg',
#  '2279706.jpg',
#  '2280533.jpg',
#  '2289073.jpg',
#  '2294024.jpg',
#  '2298395.jpg',
#  '2300380.jpg',
#  '2300382.jpg',
#  '2307973.jpg',
#  '2312089.jpg',
#  '2331371.jpg',
#  '2331507.jpg',
#  '2334595.jpg',
#  '2335458.jpg',
#  '2335819.jpg',
#  '2338417.jpg',
#  '2341151.jpg',
#  '2346157.jpg',
#  '2346158.jpg',
#  '2347374.jpg',
#  '2349186.jpg',
#  '2350569.jpg',
#  '2353183.jpg',
#  '2359387.jpg',
#  '2360965.jpg',
#  '2363121.jpg',
#  '2364723.jpg',
#  '2366013.jpg',
#  '2366015.jpg',
#  '2366332.jpg',
#  '2367161.jpg',
#  '2367164.jpg',
#  '2367877.jpg',
#  '2369442.jpg',
#  '2370432.jpg',
#  '2372556.jpg',
#  '2373908.jpg',
#  '2376007.jpg',
#  '2379329.jpg',
#  '2379336.jpg',
#  '2380817.jpg',
#  '2386164.jpg',
#  '2397813.jpg',
#  '2408178.jpg',
#  '2415153.jpg',
#  '2418210.jpg',
#  '2418213.jpg',
#  '2418215.jpg',
#  '2421538.jpg',
#  '2423867.jpg',
#  '2424848.jpg',
#  '2426785.jpg',
#  '2439008.jpg',
#  '2448030.jpg',
#  '2450524.jpg',
#  '2465197.jpg',
#  '2471020.jpg',
#  '2491765.jpg',
#  '2492388.jpg',
#  '2492390.jpg',
#  '2495595.jpg',
#  '2495600.jpg',
#  '2496194.jpg',
#  '2500253.jpg',
#  '2501335.jpg',
#  '2501677.jpg',
#  '2511204.jpg',
#  '2512959.jpg',
#  '2513005.jpg',
#  '2513901.jpg',
#  '2516427.jpg',
#  '2519876.jpg',
#  '2525039.jpg',
#  '2526098.jpg',
#  '2533979.jpg',
#  '2536248.jpg',
#  '2542750.jpg',
#  '2544608.jpg',
#  '2544619.jpg',
#  '2547588.jpg',
#  '2551841.jpg',
#  '2552779.jpg',
#  '2554103.jpg',
#  '2555514.jpg',
#  '2555517.jpg',
#  '2557939.jpg',
#  '2558494.jpg',
#  '2560212.jpg',
#  '2566668.jpg',
#  '2567000.jpg',
#  '2581882.jpg',
#  '2582893.jpg',
#  '2584655.jpg',
#  '2584659.jpg',
#  '2585933.jpg',
#  '2595963.jpg',
#  '2599513.jpg',
#  '2605012.jpg',
#  '2614761.jpg',
#  '2620113.jpg',
#  '2620121.jpg',
#  '2620122.jpg',
#  '2623591.jpg',
#  '2623958.jpg',
#  '2626209.jpg',
#  '2629639.jpg',
#  '2630096.jpg',
#  '2633989.jpg',
#  '2633994.jpg',
#  '2636059.jpg',
#  '2641921.jpg',
#  '2645804.jpg',
#  '2649216.jpg',
#  '2649218.jpg',
#  '2649535.jpg',
#  '2652720.jpg',
#  '2656373.jpg',
#  '2659840.jpg',
#  '2661528.jpg',
#  '2662131.jpg',
#  '2666174.jpg',
#  '2666655.jpg',
#  '2668080.jpg',
#  '2668362.jpg',
#  '2668364.jpg',
#  '2669359.jpg',
#  '2669738.jpg',
#  '2669740.jpg',
#  '2669787.jpg',
#  '2670248.jpg',
#  '2670255.jpg',
#  '2674151.jpg',
#  '2674154.jpg',
#  '2674161.jpg',
#  '2674615.jpg',
#  '2677142.jpg',
#  '2677722.jpg',
#  '2681398.jpg',
#  '2682507.jpg',
#  '2686125.jpg',
#  '2687195.jpg',
#  '2687595.jpg',
#  '2688639.jpg',
#  '2689595.jpg',
#  '2690849.jpg',
#  '2691286.jpg',
#  '2691506.jpg',
#  '2692107.jpg',
#  '2692197.jpg',
#  '2692644.jpg',
#  '2695161.jpg',
#  '2695710.jpg',
#  '2695711.jpg',
#  '2696832.jpg',
#  '2696865.jpg',
#  '2697214.jpg',
#  '2697215.jpg',
#  '2697801.jpg',
#  '2697803.jpg',
#  '2702021.jpg',
#  '2702069.jpg',
#  '2702381.jpg',
#  '2703509.jpg',
#  '2703516.jpg',
#  '2704878.jpg',
#  '2704900.jpg',
#  '2705257.jpg',
#  '2707617.jpg',
#  '2707681.jpg',
#  '2708321.jpg',
#  '2709243.jpg',
#  '2710650.jpg',
#  '2711116.jpg',
#  '2712415.jpg',
#  '2712416.jpg',
#  '2712425.jpg',
#  '2713141.jpg',
#  '2713760.jpg',
#  '2715511.jpg',
#  '2718774.jpg',
#  '2718775.jpg',
#  '2719167.jpg',
#  '2719598.jpg',
#  '2720152.jpg',
#  '2720154.jpg',
#  '2721373.jpg',
#  '2721389.jpg',
#  '2722994.jpg',
#  '2723970.jpg',
#  '2725122.jpg',
#  '2726582.jpg',
#  '2726764.jpg',
#  '2728638.jpg',
#  '2728651.jpg',
#  '2728882.jpg',
#  '2730607.jpg',
#  '2732660.jpg',
#  '2733111.jpg',
#  '2735279.jpg',
#  '2736149.jpg',
#  '2737489.jpg',
#  '2739099.jpg',
#  '2740041.jpg',
#  '2740839.jpg',
#  '2741178.jpg',
#  '2741468.jpg',
#  '2741686.jpg',
#  '2741688.jpg',
#  '2743445.jpg',
#  '2744087.jpg',
#  '2744724.jpg',
#  '2745057.jpg',
#  '2747304.jpg',
#  '2747460.jpg',
#  '2748659.jpg',
#  '2749028.jpg',
#  '2756816.jpg',
#  '2758003.jpg',
#  '2761555.jpg',
#  '2762069.jpg',
#  '2764012.jpg',
#  '2764353.jpg',
#  '2767414.jpg',
#  '2769644.jpg',
#  '2770989.jpg',
#  '2771851.jpg',
#  '2773615.jpg',
#  '2773620.jpg',
#  '2775966.jpg',
#  '2776364.jpg',
#  '2778068.jpg',
#  '2778081.jpg',
#  '2778084.jpg',
#  '2778088.jpg',
#  '2778092.jpg',
#  '2778130.jpg',
#  '2779977.jpg',
#  '2780006.jpg',
#  '2780029.jpg',
#  '2780052.jpg',
#  '2780084.jpg',
#  '2780101.jpg',
#  '2780114.jpg',
#  '2780162.jpg',
#  '2780170.jpg',
#  '2780171.jpg',
#  '2780176.jpg',
#  '2780178.jpg',
#  '2780182.jpg',
#  '2780187.jpg',
#  '2780200.jpg',
#  '2780201.jpg',
#  '2780208.jpg',
#  '2780209.jpg',
#  '2780211.jpg',
#  '2780679.jpg',
#  '2780682.jpg',
#  '2781581.jpg',
#  '2782122.jpg',
#  '2782139.jpg',
#  '2782140.jpg',
#  '2782143.jpg',
#  '2782147.jpg',
#  '2782155.jpg',
#  '2782161.jpg',
#  '2782175.jpg',
#  '2782181.jpg',
#  '2782195.jpg',
#  '2782208.jpg',
#  '2782211.jpg',
#  '2782212.jpg',
#  '2782213.jpg',
#  '2782216.jpg',
#  '2782235.jpg',
#  '2782241.jpg',
#  '2782242.jpg',
#  '2782247.jpg',
#  '2782251.jpg',
#  '2782255.jpg',
#  '2782257.jpg',
#  '2782260.jpg',
#  '2782262.jpg',
#  '2782270.jpg',
#  '2784032.jpg',
#  '2784155.jpg',
#  '2784172.jpg',
#  '2784187.jpg',
#  '2784196.jpg',
#  '2784211.jpg',
#  '2784213.jpg',
#  '2784216.jpg',
#  '2784218.jpg',
#  '2784219.jpg',
#  '2784223.jpg',
#  '2784225.jpg',
#  '2784227.jpg',
#  '2784231.jpg',
#  '2784235.jpg',
#  '2784236.jpg',
#  '2784239.jpg',
#  '2784242.jpg',
#  '2784249.jpg',
#  '2784253.jpg',
#  '2784263.jpg',
#  '2784265.jpg',
#  '2784269.jpg',
#  '2784271.jpg',
#  '2784278.jpg',
#  '2784279.jpg',
#  '2784283.jpg',
#  '2784289.jpg',
#  '2784295.jpg',
#  '2784297.jpg',
#  '2784299.jpg',
#  '2786121.jpg',
#  '2786154.jpg',
#  '2786155.jpg',
#  '2786159.jpg',
#  '2786160.jpg',
#  '2786163.jpg',
#  '2786197.jpg',
#  '2786202.jpg',
#  '2786204.jpg',
#  '2786213.jpg',
#  '2786217.jpg',
#  '2786221.jpg',
#  '2786223.jpg',
#  '2786240.jpg',
#  '2786249.jpg',
#  '2786250.jpg',
#  '2786269.jpg',
#  '2787793.jpg',
#  '2788194.jpg',
#  '2788196.jpg',
#  '2788210.jpg',
#  '2788221.jpg',
#  '2788224.jpg',
#  '2788225.jpg',
#  '2788230.jpg',
#  '2788233.jpg',
#  '2788245.jpg',
#  '2788248.jpg',
#  '2788255.jpg',
#  '2788257.jpg',
#  '2788258.jpg',
#  '2788260.jpg',
#  '2788262.jpg',
#  '2788271.jpg',
#  '2788279.jpg',
#  '2788283.jpg',
#  '2788284.jpg',
#  '2788288.jpg',
#  '2788289.jpg',
#  '2788300.jpg',
#  '2788332.jpg',
#  '2788339.jpg',
#  '2788341.jpg',
#  '2788343.jpg',
#  '2788350.jpg',
#  '2788355.jpg',
#  '2789486.jpg',
#  '2790230.jpg',
#  '2790232.jpg',
#  '2790235.jpg',
#  '2790255.jpg',
#  '2790259.jpg',
#  '2790260.jpg',
#  '2790279.jpg',
#  '2790291.jpg',
#  '2790306.jpg',
#  '2790314.jpg',
#  '2790347.jpg',
#  '2790348.jpg',
#  '2790355.jpg',
#  '2790377.jpg',
#  '2790393.jpg',
#  '2790405.jpg',
#  '2790506.jpg',
#  '2791669.jpg',
#  '2792282.jpg',
#  '2792283.jpg',
#  '2792284.jpg',
#  '2792285.jpg',
#  '2792289.jpg',
#  '2792303.jpg',
#  '2792307.jpg',
#  '2792310.jpg',
#  '2792312.jpg',
#  '2792319.jpg',
#  '2792330.jpg',
#  '2792339.jpg',
#  '2792357.jpg',
#  '2792363.jpg',
#  '2792376.jpg',
#  '2792384.jpg',
#  '2792386.jpg',
#  '2792389.jpg',
#  '2792393.jpg',
#  '2792394.jpg',
#  '2792396.jpg',
#  '2792402.jpg',
#  '2792403.jpg',
#  '2792420.jpg',
#  '2792421.jpg',
#  '2792423.jpg',
#  '2792424.jpg',
#  '2792425.jpg',
#  '2792432.jpg',
#  '2792439.jpg',
#  '2794307.jpg',
#  '2794319.jpg',
#  '2794325.jpg',
#  '2794344.jpg',
#  '2794348.jpg',
#  '2794351.jpg',
#  '2794360.jpg',
#  '2794382.jpg',
#  '2794383.jpg',
#  '2794384.jpg',
#  '2794393.jpg',
#  '2794397.jpg',
#  '2794403.jpg',
#  '2794432.jpg',
#  '2794436.jpg',
#  '2794437.jpg',
#  '2794447.jpg',
#  '2794452.jpg',
#  '2794453.jpg',
#  '2795268.jpg',
#  '2796336.jpg',
#  '2796340.jpg',
#  '2796342.jpg',
#  '2796347.jpg',
#  '2796359.jpg',
#  '2796372.jpg',
#  '2796376.jpg',
#  '2796377.jpg',
#  '2796385.jpg',
#  '2796393.jpg',
#  '2796405.jpg',
#  '2796407.jpg',
#  '2796418.jpg',
#  '2796421.jpg',
#  '2796425.jpg',
#  '2796426.jpg',
#  '2796427.jpg',
#  '2796433.jpg',
#  '2796463.jpg',
#  '2796481.jpg',
#  '2796482.jpg',
#  '2796491.jpg',
#  '2796495.jpg',
#  '2796497.jpg',
#  '2798358.jpg',
#  '2798365.jpg',
#  '2798369.jpg',
#  '2798371.jpg',
#  '2798384.jpg',
#  '2798388.jpg',
#  '2798392.jpg',
#  '2798397.jpg',
#  '2798410.jpg',
#  '2798412.jpg',
#  '2798424.jpg',
#  '2798425.jpg',
#  '2798431.jpg',
#  '2798436.jpg',
#  '2798439.jpg',
#  '2798444.jpg',
#  '2798451.jpg',
#  '2798455.jpg',
#  '2798457.jpg',
#  '2798465.jpg',
#  '2798475.jpg',
#  '2798476.jpg',
#  '2798480.jpg',
#  '2798481.jpg',
#  '2798490.jpg',
#  '2798491.jpg',
#  '2798499.jpg',
#  '2798514.jpg',
#  '2798525.jpg',
#  '2798527.jpg',
#  '2800098.jpg',
#  '2800421.jpg',
#  '2800424.jpg',
#  '2800430.jpg',
#  '2800440.jpg',
#  '2800443.jpg',
#  '2800445.jpg',
#  '2800447.jpg',
#  '2800448.jpg',
#  '2800465.jpg',
#  '2800471.jpg',
#  '2800475.jpg',
#  '2800488.jpg',
#  '2800489.jpg',
#  '2800491.jpg',
#  '2800500.jpg',
#  '2800510.jpg',
#  '2800511.jpg',
#  '2800526.jpg',
#  '2800530.jpg',
#  '2800542.jpg',
#  '2800552.jpg',
#  '2800567.jpg',
#  '2800570.jpg',
#  '2800574.jpg',
#  '2800582.jpg',
#  '2800584.jpg',
#  '2800585.jpg',
#  '2800593.jpg',
#  '2800595.jpg',
#  '2802031.jpg',
#  '2802493.jpg',
#  '2802494.jpg',
#  '2802496.jpg',
#  '2802501.jpg',
#  '2802502.jpg',
#  '2802503.jpg',
#  '2802505.jpg',
#  '2802520.jpg',
#  '2802535.jpg',
#  '2802558.jpg',
#  '2802599.jpg',
#  '2802600.jpg',
#  '2802608.jpg',
#  '2802610.jpg',
#  '2802611.jpg',
#  '2802614.jpg',
#  '2802615.jpg',
#  '2802623.jpg',
#  '2802630.jpg',
#  '2802631.jpg',
#  '2802635.jpg',
#  '2802636.jpg',
#  '2802649.jpg',
#  '2802654.jpg',
#  '2804501.jpg',
#  '2804517.jpg',
#  '2804592.jpg',
#  '2804593.jpg',
#  '2804594.jpg',
#  '2804605.jpg',
#  '2804606.jpg',
#  '2804613.jpg',
#  '2804617.jpg',
#  '2804618.jpg',
#  '2804620.jpg',
#  '2804643.jpg',
#  '2804654.jpg',
#  '2804664.jpg',
#  '2804682.jpg',
#  '2804684.jpg',
#  '2804712.jpg',
#  '2804719.jpg',
#  '2804723.jpg',
#  '2804743.jpg',
#  '2804746.jpg',
#  '2804747.jpg',
#  '2804753.jpg',
#  '2804756.jpg',
#  '2804760.jpg',
#  '2804762.jpg',
#  '2804763.jpg',
#  '2804764.jpg',
#  '2804765.jpg',
#  '2804766.jpg',
#  '2806102.jpg',
#  '2806236.jpg',
#  '2806614.jpg',
#  '2806616.jpg',
#  '2806622.jpg',
#  '2806629.jpg',
#  '2806639.jpg',
#  '2806659.jpg',
#  '2806665.jpg',
#  '2806672.jpg',
#  '2806673.jpg',
#  '2806676.jpg',
#  '2806701.jpg',
#  '2806707.jpg',
#  '2806709.jpg',
#  '2806712.jpg',
#  '2806720.jpg',
#  '2806722.jpg',
#  '2806725.jpg',
#  '2806740.jpg',
#  '2806745.jpg',
#  '2806749.jpg',
#  '2806750.jpg',
#  '2806763.jpg',
#  '2806772.jpg',
#  '2806775.jpg',
#  '2806780.jpg',
#  '2806784.jpg',
#  '2807078.jpg',
#  '2807422.jpg',
#  '2807424.jpg',
#  '2807429.jpg',
#  '2807431.jpg',
#  '2807457.jpg',
#  '2807578.jpg',
#  '2807636.jpg',
#  '2807712.jpg',
#  '2807929.jpg',
#  '2808660.jpg',
#  '2808678.jpg',
#  '2808679.jpg',
#  '2808682.jpg',
#  '2808683.jpg',
#  '2808688.jpg',
#  '2808735.jpg',
#  '2808738.jpg',
#  '2808748.jpg',
#  '2808757.jpg',
#  '2808758.jpg',
#  '2808786.jpg',
#  '2808791.jpg',
#  '2808795.jpg',
#  '2808796.jpg',
#  '2808798.jpg',
#  '2808815.jpg',
#  '2808829.jpg',
#  '2808835.jpg',
#  '2808977.jpg',
#  '2809175.jpg',
#  '2809399.jpg',
#  '2809690.jpg',
#  '2809762.jpg',
#  '2809765.jpg',
#  '2809929.jpg',
#  '2810136.jpg',
#  '2810205.jpg',
#  '2810465.jpg',
#  '2810538.jpg',
#  '2810542.jpg',
#  '2810562.jpg',
#  '2810736.jpg',
#  '2810737.jpg',
#  '2810738.jpg',
#  '2810739.jpg',
#  '2810749.jpg',
#  '2810771.jpg',
#  '2810772.jpg',
#  '2810775.jpg',
#  '2810777.jpg',
#  '2810782.jpg',
#  '2810791.jpg',
#  '2810795.jpg',
#  '2810809.jpg',
#  '2810813.jpg',
#  '2810815.jpg',
#  '2810816.jpg',
#  '2810834.jpg',
#  '2810837.jpg',
#  '2810840.jpg',
#  '2810860.jpg',
#  '2810864.jpg',
#  '2810868.jpg',
#  '2810880.jpg',
#  '2810881.jpg',
#  '2810891.jpg',
#  '2810892.jpg',
#  '2810893.jpg',
#  '2810895.jpg',
#  '2812139.jpg',
#  '2812710.jpg',
#  '2812746.jpg',
#  '2812759.jpg',
#  '2812767.jpg',
#  '2812772.jpg',
#  '2812790.jpg',
#  '2812801.jpg',
#  '2812807.jpg',
#  '2812811.jpg',
#  '2812817.jpg',
#  '2812819.jpg',
#  '2812821.jpg',
#  '2812822.jpg',
#  '2812823.jpg',
#  '2812824.jpg',
#  '2812825.jpg',
#  '2812836.jpg',
#  '2812837.jpg',
#  '2812845.jpg',
#  '2812846.jpg',
#  '2812854.jpg',
#  '2812855.jpg',
#  '2812879.jpg',
#  '2812896.jpg',
#  '2812907.jpg',
#  '2812917.jpg',
#  '2812924.jpg',
#  '2812929.jpg',
#  '2812930.jpg',
#  ...]

# %%
preds_  = torch.argmax(preds,1)+1
preds_
# Out:
# tensor([4, 4, 4,  ..., 4, 4, 4])

# %%
preds_ = preds_.numpy()
preds_
# Out:
# array([4, 4, 4, 2, ..., 4, 4, 4, 4])

# %%
pd.Series(preds_).value_counts()
# Out:
# 1    913
# 5    521
# 2    502
# 3    388
# 4    356
# dtype: int64

# %%
predsDF = pd.DataFrame()
predsDF['image'] = imgName
predsDF['category'] = preds_
predsDF.head(20)
# Out:
#           image  category
# 0   1007700.jpg         4
# 1   1011369.jpg         4
# 2   1051155.jpg         4
# 3   1062001.jpg         2
# 4   1069397.jpg         4
# 5   1072861.jpg         4
# 6   1097264.jpg         4
# 7   1098763.jpg         2
# 8   1098766.jpg         2
# 9   1101145.jpg         4
# 10  1114371.jpg         4
# 11  1114781.jpg         4
# 12  1115492.jpg         4
# 13  1121306.jpg         1
# 14  1123736.jpg         2
# 15  1124946.jpg         2
# 16  1125700.jpg         4
# 17  1127236.jpg         2
# 18  1127336.jpg         2
# 19  1130300.jpg         4

# %%
t.head(20)
# Out:
#           image
# 0   1007700.jpg
# 1   1011369.jpg
# 2   1051155.jpg
# 3   1062001.jpg
# 4   1069397.jpg
# 5   1072861.jpg
# 6   1097264.jpg
# 7   1098763.jpg
# 8   1098766.jpg
# 9   1101145.jpg
# 10  1114371.jpg
# 11  1114781.jpg
# 12  1115492.jpg
# 13  1121306.jpg
# 14  1123736.jpg
# 15  1124946.jpg
# 16  1125700.jpg
# 17  1127236.jpg
# 18  1127336.jpg
# 19  1130300.jpg

# %%
sum(predsDF['image'] == t['image']) == t.shape[0]
# Out:
# True

# %%
predsDF.to_csv('preds_densenet121.csv',index=False)
from IPython.display import FileLink, FileLinks
FileLink('preds_densenet121.csv')
# Out:
# /kaggle/working/preds_densenet121.csv
